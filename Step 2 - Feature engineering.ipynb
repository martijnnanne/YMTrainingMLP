# %%
import pandas as pd

# %%
train_data = pd.read_csv('data_assignment2/train_fact.csv')
ext_df = pd.read_csv('data_assignment2/external_data.csv')
prev_df = pd.read_csv('data_assignment2/prev_filtered.csv')

# %% [markdown]
# # Feature engineering
#
# Feature engineering is all about creating more information from the information you have. Not all raw data can be used as is.
#
# For example categorical variables cannot be used "as is" therefore we have to one hot encode these variables to use them. Here is one example for gender.
#
#
# We usually have two types of variables, continuous and categorical
#
# Continuous variables are basically numeric features, it can take any numerical value. In this dataset DAYS BIRTH is an example of a continuous feature. These features are probably a good starting point since we can use them directly in a machine learning model.
#
# Categorical variables are different as in that a variable is categorized in two or more categories. In this dataset GENDER is a categorical variable. It has just three categories: male, female or XNA. Often categorical variables are often strings and have to be transformed in some way as they cannot be used directly in a machine learning model. A machine learning model works with numbers, not with strings.
#
#
# # The desired state of the data before we can apply machine learning
#
# Before we can train a machine learning we have to transform the dataset into a format that a machine learning model can use.
#
# As mentioned earlier, a machine learning model expects numbers, there should be no string columns.
#
# Q1: how are we going to transform the string columns to a numerical column(s)?
#
# We want to extract as much data from our dataset as possible.
#
# Q2: how can we extract more information from the dataset then the data already provides?
#
# Eventually we want to get to a situation where each column is a feature and the target variable in the end.
#
# Eg:
#
# feat_1, feat_2, feat_3, 'TARGET'

# %%
train_data = pd.get_dummies(train_data, columns=['CODE_GENDER'])

# %%
train_data.shape
# Out:
# (50000, 124)

# %% [markdown]
# Here is an example of how we can add more information such as "income per child"

# %%
train_data['income_per_child'] = train_data['AMT_INCOME_TOTAL'] / (train_data['CNT_CHILDREN'] + 1)

# %% [markdown]
# The historical data is more complex, since we only have current records in our prediction table, we have to transform the history to a single row of variables to add to our prediction table.

# %%
prev_agg = prev_df.groupby('SK_ID_CURR').agg({
    'AMT_CREDIT': ['min', 'max', 'mean', 'sum']
})
prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])

# %%
ext_df = pd.read_csv('data_assignment2/external_data.csv')
ext_agg = ext_df.groupby('SK_ID_CURR').agg({
    'AMT_CREDIT_SUM': ['min', 'max', 'mean', 'sum']
})
ext_agg.columns = pd.Index(
    ['EXT_' + e[0] + "_" + e[1].upper() for e in ext_agg.columns.tolist()])

# %% [markdown]
# We can now merge the aggregates with our prediction table.

# %%
train_data = pd.merge(train_data, prev_agg, how='left', on='SK_ID_CURR')
train_data = pd.merge(train_data, ext_agg, how='left', on='SK_ID_CURR')

# %%
train_data
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0          100002       1         Cash loans            N               Y
# 1          100003       0         Cash loans            N               N
# 2          100004       0    Revolving loans            Y               Y
# 3          100006       0         Cash loans            N               Y
# 4          100007       0         Cash loans            N               Y
# 5          100008       0         Cash loans            N               Y
# 6          100009       0         Cash loans            Y               Y
# 7          100010       0         Cash loans            Y               Y
# 8          100011       0         Cash loans            N               Y
# 9          100012       0    Revolving loans            N               Y
# 10         100014       0         Cash loans            N               Y
# 11         100015       0         Cash loans            N               Y
# 12         100016       0         Cash loans            N               Y
# 13         100017       0         Cash loans            Y               N
# 14         100018       0         Cash loans            N               Y
# 15         100019       0         Cash loans            Y               Y
# 16         100020       0         Cash loans            N               N
# 17         100021       0    Revolving loans            N               Y
# 18         100022       0    Revolving loans            N               Y
# 19         100023       0         Cash loans            N               Y
# 20         100024       0    Revolving loans            Y               Y
# 21         100025       0         Cash loans            Y               Y
# 22         100026       0         Cash loans            N               N
# 23         100027       0         Cash loans            N               Y
# 24         100029       0         Cash loans            Y               N
# 25         100030       0         Cash loans            N               Y
# 26         100031       1         Cash loans            N               Y
# 27         100032       0         Cash loans            N               Y
# 28         100033       0         Cash loans            Y               Y
# 29         100034       0    Revolving loans            N               Y
# ...           ...     ...                ...          ...             ...
# 49970      157843       0         Cash loans            N               Y
# 49971      157844       0         Cash loans            N               Y
# 49972      157845       0         Cash loans            N               N
# 49973      157846       1         Cash loans            N               Y
# 49974      157848       0         Cash loans            N               Y
# 49975      157849       0         Cash loans            N               Y
# 49976      157850       1         Cash loans            N               Y
# 49977      157851       0         Cash loans            N               Y
# 49978      157852       0         Cash loans            N               N
# 49979      157853       0         Cash loans            N               N
# 49980      157854       0         Cash loans            N               N
# 49981      157855       0         Cash loans            N               Y
# 49982      157856       0         Cash loans            Y               Y
# 49983      157857       0    Revolving loans            Y               N
# 49984      157858       0         Cash loans            N               N
# 49985      157860       0         Cash loans            N               Y
# 49986      157861       1         Cash loans            Y               N
# 49987      157862       0         Cash loans            Y               Y
# 49988      157863       0    Revolving loans            Y               Y
# 49989      157865       0    Revolving loans            N               Y
# 49990      157867       0    Revolving loans            N               Y
# 49991      157868       0         Cash loans            Y               Y
# 49992      157869       0    Revolving loans            N               Y
# 49993      157870       0    Revolving loans            N               N
# 49994      157871       0         Cash loans            N               N
# 49995      157872       0         Cash loans            N               N
# 49996      157873       0         Cash loans            N               N
# 49997      157874       0         Cash loans            N               Y
# 49998      157875       0         Cash loans            N               Y
# 49999      157876       0         Cash loans            N               Y
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                 0        202500.000    406597.5      24700.5
# 1                 0        270000.000   1293502.5      35698.5
# 2                 0         67500.000    135000.0       6750.0
# 3                 0        135000.000    312682.5      29686.5
# 4                 0        121500.000    513000.0      21865.5
# 5                 0         99000.000    490495.5      27517.5
# 6                 1        171000.000   1560726.0      41301.0
# 7                 0        360000.000   1530000.0      42075.0
# 8                 0        112500.000   1019610.0      33826.5
# 9                 0        135000.000    405000.0      20250.0
# 10                1        112500.000    652500.0      21177.0
# 11                0         38419.155    148365.0      10678.5
# 12                0         67500.000     80865.0       5881.5
# 13                1        225000.000    918468.0      28966.5
# 14                0        189000.000    773680.5      32778.0
# 15                0        157500.000    299772.0      20160.0
# 16                0        108000.000    509602.5      26149.5
# 17                1         81000.000    270000.0      13500.0
# 18                0        112500.000    157500.0       7875.0
# 19                1         90000.000    544491.0      17563.5
# 20                0        135000.000    427500.0      21375.0
# 21                1        202500.000   1132573.5      37561.5
# 22                1        450000.000    497520.0      32521.5
# 23                0         83250.000    239850.0      23850.0
# 24                2        135000.000    247500.0      12703.5
# 1            484191.000000         1.452573e+06                22248.00
# 2             20106.000000         2.010600e+04                94500.00
# 3            291695.500000         2.625260e+06                     NaN
# 4            166638.750000         9.998325e+05               146250.00
# 5            162767.700000         8.138385e+05                95134.50
# 6             70137.642857         4.909635e+05                35770.50
# 7            260811.000000         2.608110e+05               315000.00
# 8            261840.375000         1.047362e+06                54000.00
# 9             74119.500000         2.964780e+05                     NaN
# 10           102834.000000         2.056680e+05                26194.50
# 11            67077.000000         6.707700e+04                89752.50
# 12           106221.375000         4.248855e+05                22086.00
# 13           175565.250000         3.511305e+05                25231.50
# 14           285989.591250         1.143958e+06                     NaN
# 15           104683.500000         1.046835e+05               270000.00
# 16            41706.000000         8.341200e+04                16200.00
# 17           153615.750000         9.216945e+05                     NaN
# 18           103203.000000         1.032030e+05               292500.00
# 19           113517.000000         4.540680e+05                22500.00
# 20                     NaN                  NaN                     NaN
# 21           295425.781875         2.363406e+06              2452500.00
# 22           292281.000000         8.768430e+05              1350000.00
# 23           173795.625000         6.951825e+05                40297.50
# 24           126000.000000         1.260000e+05                24016.50
# 25            32534.643750         3.904157e+05                    0.00
# 26                     NaN                  NaN                90000.00
# 27            42255.000000         4.225500e+04               152910.00
# 28            53329.500000         5.332950e+04               675000.00
# 29           112527.000000         2.250540e+05                     NaN
# ...                    ...                  ...                     ...
# 49970        139719.750000         8.383185e+05                20741.04
# 49971        187353.500000         1.686182e+06                94621.50
# 49972        218882.700000         1.094414e+06                40707.00
# 49973        923911.071429         6.467378e+06                16875.00
# 49974        147330.000000         1.473300e+05                27630.00
# 49975        158663.250000         3.173265e+05                     NaN
# 49976        201578.250000         1.209470e+06               540000.00
# 49977        220708.800000         2.207088e+06                90018.00
# 49978         71955.000000         7.195500e+04                     NaN
# 49979        111235.500000         1.112355e+05                    0.00
# 49980        102687.000000         6.161220e+05                90000.00
# 49981         79433.000000         7.148970e+05               157500.00
# 49982         79685.100000         7.968510e+05                11250.00
# 49983         54418.500000         5.441850e+04                     NaN
# 49984         78750.000000         1.575000e+05               125914.50
# 49985        248236.500000         2.234128e+06                78705.00
# 49986         56301.000000         1.689030e+05                65700.00
# 49987         26640.000000         1.332000e+05                15322.50
# 49988         72806.625000         5.824530e+05                22450.50
# 49989        162337.500000         3.246750e+05               124650.00
# 49990         42205.500000         2.110275e+05                    0.00
# 49991        109115.235000         2.182305e+05               142056.00
# 49992                  NaN                  NaN                     NaN
# 49993        364199.062500         2.913592e+06                    0.00
# 49994                  NaN                  NaN               202500.00
# 49995        143278.500000         4.298355e+05               324000.00
# 49996        237778.875000         9.511155e+05                67500.00
# 49997        672510.326087         1.546774e+07                    0.00
# 49998        150907.500000         1.509075e+05                64777.50
# 49999         81717.750000         1.634355e+05                23729.85
#
#        EXT_AMT_CREDIT_SUM_MAX  EXT_AMT_CREDIT_SUM_MEAN  EXT_AMT_CREDIT_SUM_SUM
# 0                  450000.000             1.081319e+05              865055.565
# 1                  810000.000             2.543501e+05             1017400.500
# 2                   94537.800             9.451890e+04              189037.800
# 3                         NaN                      NaN                     NaN
# 4                  146250.000             1.462500e+05              146250.000
# 5                  267606.000             1.561485e+05              468445.500
# 6                 1777500.000             2.667118e+05             4800811.500
# 7                  675000.000             4.950000e+05              990000.000
# 8                  145242.000             1.088071e+05              435228.300
# 9                         NaN                      NaN                     NaN
# 10                 900000.000             3.412416e+05             2729932.425
# 11                 131103.000             1.023739e+05              409495.500
# 12                  91264.500             6.785486e+04              474984.000
# 13                 315000.000             1.432950e+05              859770.000
# 14                        NaN                      NaN                     NaN
# 15                 450000.000             3.600000e+05              720000.000
# 16                 135000.000             4.987125e+04              199485.000
# 17                        NaN                      NaN                     NaN
# 18                 765000.000             5.287500e+05             1057500.000
# 19                 444078.000             1.265917e+05             1645692.345
# 20                        NaN                      NaN                     NaN
# 21                2452500.000             2.452500e+06             2452500.000
# 22                2700000.000             1.875000e+06             5625000.000
# 23                 427500.000             2.084325e+05              625297.500
# 24                3735000.000             1.857008e+06             7428033.000
# 25                 508500.000             1.072385e+05              643430.970
# 26                1350000.000             5.672359e+05             3970651.500
# 27                 454500.000             3.177900e+05             1271160.000
# 28                 675000.000             6.750000e+05              675000.000
# 29                        NaN                      NaN                     NaN
# ...                       ...                      ...                     ...
# 49970              675000.000             1.262765e+05             1767870.540
# 49971              507555.000             2.250428e+05             1125213.840
# 49972              270000.000             1.696530e+05             1017918.000
# 49973             1012500.000             3.582570e+05             2149542.000
# 49974               27630.000             2.763000e+04               27630.000
# 49975                     NaN                      NaN                     NaN
# 49976              540000.000             5.400000e+05              540000.000
# 49977              492412.500             2.376968e+05             1426180.500
# 49978                     NaN                      NaN                     NaN
# 49979              342000.000             1.179658e+05             1061692.515
# 49980              121899.555             1.059498e+05              211899.555
# 49981              157500.000             1.575000e+05              157500.000
# 49982              180000.000             8.550000e+04              342000.000
# 49983                     NaN                      NaN                     NaN
# 49984              675000.000             3.172393e+05             2537914.500
# 49985              900000.000             2.848410e+05             1424205.000
# 49986               65700.000             6.570000e+04               65700.000
# 49987              540000.000             2.083005e+05             2291305.500
# 49988              283500.000             1.132062e+05             1698093.000
# 49989              124650.000             1.246500e+05              124650.000
# 49990              498150.000             1.420891e+05             1420890.750
# 49991              149755.500             1.459058e+05              291811.500
# 49992                     NaN                      NaN                     NaN
# 49993               88690.500             4.434525e+04               88690.500
# 49994              441000.000             3.217500e+05              643500.000
# 49995              324000.000             3.240000e+05              324000.000
# 49996              315000.000             2.025000e+05              810000.000
# 49997              557158.500             1.080873e+05             2486008.890
# 49998             1436170.500             3.215660e+05             2572528.185
# 49999               90000.000             5.686493e+04              113729.850
#
# [50000 rows x 133 columns]

# %%
train_data.shape
# Out:
# (50000, 133)

# %% [markdown]
# You can see we already added 9 new features!

# %% [markdown]
# # Your turn!
#
# What other features can you come up with?
#
# - What features have to be transformed, eg categorical variables, transformations over the income etc.
# - How can we extract more value from our history?
# - What other creative features can you come up with?
#
# Some ideas:
#
# - What's the term of the loan?
# - How many times did someone pay late in the past?
# - How many times did a previous attempt get rejected?
# - Time might be important, more recent information might be more relevant then earlier information
